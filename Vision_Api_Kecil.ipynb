# %% [markdown]
# KELOMPOK 5
# CAMPUS FIRE GUARD

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.6/922.6 kB 15.1 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="R4AJrd9f5p5vxr0Wjwu3")
project = rf.workspace("firedataset-blbxu").project("small-fire-dataset-eypjj")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to small-fire-dataset-1 in yolov8:: 100%|██████████| 232/232 [00:00<00:00, 4676.87it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/small-fire-dataset-1/data.yaml epochs=60 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 253MB/s]
# Ultralytics 8.3.86 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
Image(filename='runs/detect/train/confusion_matrix.png')

# %%
Image(filename='runs/detect/train/results.png')

# %%
Image(filename='runs/detect/train/val_batch0_labels.jpg')
